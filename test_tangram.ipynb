# %%
import os
import sys
import scanpy as sc
import pandas as pd
import numpy as np

# %%
spatial_adata = sc.read('./data/STW-M-Brain-Stereo-seq-1/coronal_1.bin50.adata_sp_ann.clusters.h5ad')
sc_adata = sc.read('./data/STW-M-Brain-Stereo-seq-1/coronal_1.bin50.adata_sc.clusters.h5ad')
# Out:
# WARNING: Your filename has more than two extensions: ['.bin50', '.adata_sp_ann', '.clusters', '.h5ad'].
# Only considering the two last: ['.clusters', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.bin50', '.adata_sp_ann', '.clusters', '.h5ad'].
# Only considering the two last: ['.clusters', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.bin50', '.adata_sc', '.clusters', '.h5ad'].
# Only considering the two last: ['.clusters', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.bin50', '.adata_sc', '.clusters', '.h5ad'].
# Only considering the two last: ['.clusters', '.h5ad'].

# %%
sc_adata.var.index
# Out:
# Index(['0610005c13rik', '0610007n19rik', '0610007p14rik', '0610009b14rik',
#        '0610009b22rik', '0610009d07rik', '0610009e02rik', '0610009l18rik',
#        '0610009o20rik', '0610010f05rik',
#        ...
#        'n-r5s76', 'n-r5s77', 'n-r5s79', 'n-r5s8', 'n-r5s86', 'n-r5s87',
#        'n-r5s88', 'n-r5s90', 'n-r5s92', 'n-r5s95'],
#       dtype='object', length=21300)

# %%
sc.pl.spatial(spatial_adata, color=["cell_type"],library_id=None,spot_size=1,save='STW-M-Brain-Stereo-seq-1_spatial_tg_ann.pdf')
# Out:
# WARNING: saving figure to file figures/showSTW-M-Brain-Stereo-seq-1_spatial_tg_ann.pdf

# %%
s="sss"
type(s)
# Out:
# str
